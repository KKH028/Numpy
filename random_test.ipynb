# %%
import numpy as np

# %% [markdown]
# # numpy.random.rand
#
# Create an array of the given shape and populate it with random samples from a uniform distribution over [0, 1).

# %%
np.random.rand(3,2)
# Out:
# array([[0.67947332, 0.89635596],
#        [0.88439377, 0.20699258],
#        [0.49199741, 0.63281576]])

# %% [markdown]
# # [numpy.random.randn](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randn.html)
#
# 정규 분포 밀도 함수에서 $Z={\frac {X-\mu}{\sigma}$를 통해 X(원점수)를 Z(Z점수)로 정규화함으로써 평균이 0, 표준편차가 1인 표준정규분포를 얻을 수 있다.[1]
#
# z-분포라고도 부른다. z-분포로 하는 검정(test)을 z검정(z-test)이라고 한다.

# %%
np.random.randn()
# Out:
# 1.1076851608958957

# %%
testrandn = np.random.randn(1,3)
print("testrandn=", testrandn)
print()

testrandn = np.random.randn(1,3)
print("testrandn=", testrandn)
print()

testrandn = np.random.randn(1,3)
print("testrandn=", testrandn)
print()

testrandn = np.random.randn(1,3)
print("testrandn=", testrandn)
# Out:
# testrandn= [[-1.9590473  -1.19859706  1.0165838 ]]
#
# testrandn= [[ 1.23590829 -1.33241392  0.05238098]]
#
# testrandn= [[1.20281027 0.77096005 1.01035126]]
#
# testrandn= [[-0.32654838 -0.24662327  0.09337359]]

# %%
np.random.seed(1)

testrandn = np.random.randn(1,3)
print("testrandn=", testrandn)
print()
# Out:
# testrandn= [[ 1.62434536 -0.61175641 -0.52817175]]
